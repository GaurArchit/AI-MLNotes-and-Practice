# %%
print('Hello')
# Out:
# Hello

# %%
2+3
# Out:
# 5

# %%
print(for i in range(10))
# Out:
#   Cell In[3], line 1
#     print(for i in range(10))
#           ^
# SyntaxError: invalid syntax

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
763638812/1210854977
# Out:
# 0.6306608359425359

# %%
import pandas as pd

# %%
##df_csv=pd.read_csv('popularity.csv')
df_csv=pd.read_csv('popularity.csv',sep=',',header=0,na_values=['NA','N/A','--'],usecols=['url',' timedelta'],dtype={'url':str,' timedelta':float},nrows=10)
print(df_csv.head(20))
# Out:
#                                                  url   timedelta
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# 5   http://mashable.com/2013/01/07/beewi-smart-toys/       731.0
# 6  http://mashable.com/2013/01/07/bodymedia-armba...       731.0
# 7   http://mashable.com/2013/01/07/canon-poweshot-n/       731.0
# 8  http://mashable.com/2013/01/07/car-of-the-futu...       731.0
# 9  http://mashable.com/2013/01/07/chuck-hagel-web...       731.0

# %%
df=pd.DataFrame(df_csv)

# %%
df
# Out:
#                                                  url   timedelta
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# 5   http://mashable.com/2013/01/07/beewi-smart-toys/       731.0
# 6  http://mashable.com/2013/01/07/bodymedia-armba...       731.0
# 7   http://mashable.com/2013/01/07/canon-poweshot-n/       731.0
# 8  http://mashable.com/2013/01/07/car-of-the-futu...       731.0
# 9  http://mashable.com/2013/01/07/chuck-hagel-web...       731.0

# %%
df.to_csv('dummy_set_practive.csv',index=False,header=True)

# %%
# Data Cleaning 
df.head(3)
# Out:
#                                                  url   timedelta
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0

# %%
# Data Cleaning module 

csv_path='bank_marketing_updated_v1.csv'

df1=pd.read_csv(csv_path,sep=',',header=2,na_values=['NA','N/A','--'],usecols=['salary','balance'],nrows=5)

df1
if (df1['salary'] == 0).any():
    print("yes")
# Out:
# yes
